# %% [markdown]
# # WeatherPy
# ----
#
# ### Analysis
# * The weather appears to get significantly colder as the Latitude increases while a comparable negative Latitue does not see the same decrease in Temperature
# * There appears to be no strong relationship between Latitude and Humidity but Humidity shares the same relationship as Temperature to Latitude where the negative Latitudes experience less of a dreacrease in Humidity than the positive Latitudes do
# * There doesn't appear to be a relationship between Wind Speed or Cloudiness and Latitude, however there seems to be a few cities that are experiencing some Wind Speed around 30-40 mph

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import json

# Import API key
from config import api_keys

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 616

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
City = []
Country = []
Lat = []
Lng = []
Date = []
Cloudiness = []
Humidity = []
Max_Temp = [] 
Wind_Speed = []

base_url = 'https://api.openweathermap.org/data/2.5/weather?q={0}&appid={1}&units=imperial'

counter=1

#loop through cities to request the weather data and store each parameter in an array
for i in range(len(cities)):
    
    target_city = cities[i]
    url = base_url.format(target_city,api_keys)

    response = requests.get(url).json()

    try:
        print("Processing Record " + str(counter) + " of " + str(len(cities)) + ", "+ str(target_city) + ".")
        
        City.append(response['name'])
        Country.append(response['sys']['country'])
        Lat.append(response['coord']['lat'])
        Lng.append(response['coord']['lon'])
        Date.append(response['dt'])
        Cloudiness.append(response['clouds']['all'])
        Humidity.append(response['main']['humidity'])
        Max_Temp.append(response['main']['temp_max'])
        Wind_Speed.append(response['wind']['speed'])
        
    except (KeyError, IndexError):
        print("City not found. Skipping...")
        
    counter = counter+1
# Out:
# Processing Record 1 of 616, comodoro rivadavia.
# Processing Record 2 of 616, avarua.
# Processing Record 3 of 616, hermanus.
# Processing Record 4 of 616, leningradskaya.
# Processing Record 5 of 616, ushuaia.
# Processing Record 6 of 616, san cristobal.
# Processing Record 7 of 616, itapecerica.
# Processing Record 8 of 616, tallahassee.
# Processing Record 9 of 616, tiksi.
# Processing Record 10 of 616, dikson.
# Processing Record 11 of 616, mana.
# Processing Record 12 of 616, sao joao da barra.
# Processing Record 13 of 616, taolanaro.
# City not found. Skipping...
# Processing Record 14 of 616, albany.
# Processing Record 15 of 616, tsihombe.
# City not found. Skipping...
# Processing Record 16 of 616, san luis.
# Processing Record 17 of 616, puerto ayora.
# Processing Record 18 of 616, sand springs.
# Processing Record 19 of 616, fortuna.
# Processing Record 20 of 616, celestun.
# Processing Record 21 of 616, hithadhoo.
# Processing Record 22 of 616, port macquarie.
# Processing Record 23 of 616, seydi.
# Processing Record 24 of 616, szczecinek.
# Processing Record 25 of 616, provideniya.
# Processing Record 26 of 616, torbay.
# Processing Record 27 of 616, cape town.
# Processing Record 28 of 616, salalah.
# Processing Record 29 of 616, guru har sahai.
# Processing Record 30 of 616, taywarah.
# Processing Record 31 of 616, gorom-gorom.
# Processing Record 32 of 616, ilulissat.
# Processing Record 33 of 616, atuona.
# Processing Record 34 of 616, northam.
# Processing Record 35 of 616, tuktoyaktuk.
# Processing Record 36 of 616, udon thani.
# Processing Record 37 of 616, kholm.
# Processing Record 38 of 616, castro.
# Processing Record 39 of 616, luwuk.
# Processing Record 40 of 616, bredasdorp.
# Processing Record 41 of 616, port blair.
# Processing Record 42 of 616, tonneins.
# Processing Record 43 of 616, ayan.
# Processing Record 44 of 616, bilma.
# Processing Record 45 of 616, mataura.
# Processing Record 46 of 616, sao filipe.
# Processing Record 47 of 616, yaan.
# Processing Record 48 of 616, palabuhanratu.
# City not found. Skipping...
# Processing Record 49 of 616, bluff.
# Processing Record 50 of 616, busselton.
# Processing Record 51 of 616, rikitea.
# Processing Record 52 of 616, turochak.
# Processing Record 53 of 616, victoria.
# Processing Record 54 of 616, illoqqortoormiut.
# City not found. Skipping...
# Processing Record 55 of 616, atar.
# Processing Record 56 of 616, hambantota.
# Processing Record 57 of 616, souillac.
# Processing Record 58 of 616, qaanaaq.
# Processing Record 59 of 616, freeport.
# Processing Record 60 of 616, kibala.
# Processing Record 61 of 616, barentsburg.
# City not found. Skipping...
# Processing Record 62 of 616, tevaitoa.
# Processing Record 63 of 616, jamestown.
# Processing Record 64 of 616, bengkulu.
# City not found. Skipping...
# Processing Record 65 of 616, vaitupu.
# City not found. Skipping...
# Processing Record 66 of 616, nizhneyansk.
# City not found. Skipping...
# Processing Record 67 of 616, avera.
# Processing Record 68 of 616, butaritari.
# Processing Record 69 of 616, srednekolymsk.
# Processing Record 70 of 616, barrow.
# Processing Record 71 of 616, nyurba.
# Processing Record 72 of 616, belushya guba.
# City not found. Skipping...
# Processing Record 73 of 616, kodiak.
# Processing Record 74 of 616, codrington.
# Processing Record 75 of 616, komsomolskiy.
# Processing Record 76 of 616, bemidji.
# Processing Record 77 of 616, kosgi.
# City not found. Skipping...
# Processing Record 78 of 616, hasaki.
# Processing Record 79 of 616, necochea.
# Processing Record 80 of 616, saleaula.
# City not found. Skipping...
# Processing Record 81 of 616, alausi.
# Processing Record 82 of 616, wuwei.
# Processing Record 83 of 616, new norfolk.
# Processing Record 84 of 616, ayr.
# Processing Record 85 of 616, chuy.
# Processing Record 86 of 616, bandarbeyla.
# Processing Record 87 of 616, tatawin.
# City not found. Skipping...
# Processing Record 88 of 616, kiama.
# Processing Record 89 of 616, zhigansk.
# Processing Record 90 of 616, korhogo.
# Processing Record 91 of 616, punta arenas.
# Processing Record 92 of 616, grand river south east.
# City not found. Skipping...
# Processing Record 93 of 616, kharovsk.
# Processing Record 94 of 616, awbari.
# Processing Record 95 of 616, alto araguaia.
# Processing Record 96 of 616, adrar.
# Processing Record 97 of 616, price.
# Processing Record 98 of 616, aflu.
# City not found. Skipping...
# Processing Record 99 of 616, faanui.
# Processing Record 100 of 616, chara.
# Processing Record 101 of 616, tiznit.
# Processing Record 102 of 616, arraial do cabo.
# Processing Record 103 of 616, kajaani.
# Processing Record 104 of 616, mayo.
# Processing Record 105 of 616, nador.
# Processing Record 106 of 616, bethel.
# Processing Record 107 of 616, saint-philippe.
# Processing Record 108 of 616, vaini.
# Processing Record 109 of 616, mar del plata.
# Processing Record 110 of 616, leningradskiy.
# Processing Record 111 of 616, teya.
# Processing Record 112 of 616, kapaa.
# Processing Record 113 of 616, haines junction.
# Processing Record 114 of 616, hobart.
# Processing Record 115 of 616, georgetown.
# Processing Record 116 of 616, east london.
# Processing Record 117 of 616, hamilton.
# Processing Record 118 of 616, areosa.
# Processing Record 119 of 616, thompson.
# Processing Record 120 of 616, yellowknife.
# Processing Record 121 of 616, morant bay.
# Processing Record 122 of 616, kamenka.
# Processing Record 123 of 616, amderma.
# City not found. Skipping...
# Processing Record 124 of 616, new iberia.
# Processing Record 125 of 616, longyearbyen.
# Processing Record 126 of 616, kennett.
# Processing Record 127 of 616, saint george.
# Processing Record 128 of 616, sentyabrskiy.
# City not found. Skipping...
# Processing Record 129 of 616, saryshagan.
# City not found. Skipping...
# Processing Record 130 of 616, santa isabel.
# Processing Record 131 of 616, cherskiy.
# Processing Record 132 of 616, pustoshka.
# Processing Record 133 of 616, lingyuan.
# Processing Record 134 of 616, vestmannaeyjar.
# Processing Record 135 of 616, klaksvik.
# Processing Record 136 of 616, richards bay.
# Processing Record 137 of 616, nikolskoye.
# Processing Record 138 of 616, ada.
# Processing Record 139 of 616, launceston.
# Processing Record 140 of 616, el astillero.
# Processing Record 141 of 616, hilo.
# Processing Record 142 of 616, walvis bay.
# Processing Record 143 of 616, sur.
# Processing Record 144 of 616, starup.
# Processing Record 145 of 616, aleksandrov gay.
# Processing Record 146 of 616, lhuntshi.
# City not found. Skipping...
# Processing Record 147 of 616, novo cruzeiro.
# Processing Record 148 of 616, longyan.
# Processing Record 149 of 616, bambous virieux.
# Processing Record 150 of 616, lolua.
# City not found. Skipping...
# Processing Record 151 of 616, abu zabad.
# Processing Record 152 of 616, warren.
# Processing Record 153 of 616, port alfred.
# Processing Record 154 of 616, caravelas.
# Processing Record 155 of 616, aklavik.
# Processing Record 156 of 616, itaituba.
# Processing Record 157 of 616, conde.
# Processing Record 158 of 616, san quintin.
# Processing Record 159 of 616, port elizabeth.
# Processing Record 160 of 616, torgelow.
# Processing Record 161 of 616, bauchi.
# Processing Record 162 of 616, namatanai.
# Processing Record 163 of 616, voh.
# Processing Record 164 of 616, dzhusaly.
# City not found. Skipping...
# Processing Record 165 of 616, mys shmidta.
# City not found. Skipping...
# Processing Record 166 of 616, lompoc.
# Processing Record 167 of 616, clyde river.
# Processing Record 168 of 616, beyneu.
# Processing Record 169 of 616, vestmanna.
# Processing Record 170 of 616, kahului.
# Processing Record 171 of 616, kaitangata.
# Processing Record 172 of 616, narsaq.
# Processing Record 173 of 616, atasu.
# Processing Record 174 of 616, santa cruz.
# Processing Record 175 of 616, podor.
# Processing Record 176 of 616, saldanha.
# Processing Record 177 of 616, fare.
# Processing Record 178 of 616, bella vista.
# Processing Record 179 of 616, zaria.
# Processing Record 180 of 616, la ronge.
# Processing Record 181 of 616, bonavista.
# Processing Record 182 of 616, nanortalik.
# Processing Record 183 of 616, grindavik.
# Processing Record 184 of 616, westport.
# Processing Record 185 of 616, taganak.
# Processing Record 186 of 616, sao felix do xingu.
# Processing Record 187 of 616, goderich.
# Processing Record 188 of 616, paramonga.
# Processing Record 189 of 616, chokurdakh.
# Processing Record 190 of 616, carnarvon.
# Processing Record 191 of 616, kuche.
# City not found. Skipping...
# Processing Record 192 of 616, eruwa.
# Processing Record 193 of 616, ust-tsilma.
# Processing Record 194 of 616, hovd.
# Processing Record 195 of 616, coihaique.
# Processing Record 196 of 616, ambilobe.
# Processing Record 197 of 616, buraydah.
# Processing Record 198 of 616, jaumave.
# Processing Record 199 of 616, boden.
# Processing Record 200 of 616, yinchuan.
# Processing Record 201 of 616, ostrovnoy.
# Processing Record 202 of 616, khatanga.
# Processing Record 203 of 616, omboue.
# Processing Record 204 of 616, husavik.
# Processing Record 205 of 616, bathsheba.
# Processing Record 206 of 616, nantucket.
# Processing Record 207 of 616, haldensleben.
# Processing Record 208 of 616, west plains.
# Processing Record 209 of 616, port hardy.
# Processing Record 210 of 616, atambua.
# Processing Record 211 of 616, laguna.
# Processing Record 212 of 616, oriximina.
# Processing Record 213 of 616, lyuban.
# Processing Record 214 of 616, ponta do sol.
# Processing Record 215 of 616, waipawa.
# Processing Record 216 of 616, burica.
# City not found. Skipping...
# Processing Record 217 of 616, saskylakh.
# Processing Record 218 of 616, piacabucu.
# Processing Record 219 of 616, riyadh.
# Processing Record 220 of 616, kruisfontein.
# Processing Record 221 of 616, gharo.
# Processing Record 222 of 616, khonuu.
# City not found. Skipping...
# Processing Record 223 of 616, quatre cocos.
# Processing Record 224 of 616, cabo san lucas.
# Processing Record 225 of 616, mehamn.
# Processing Record 226 of 616, karasjok.
# Processing Record 227 of 616, moerai.
# Processing Record 228 of 616, erdenet.
# Processing Record 229 of 616, lagoa.
# Processing Record 230 of 616, galiwinku.
# City not found. Skipping...
# Processing Record 231 of 616, manadhoo.
# Processing Record 232 of 616, olafsvik.
# City not found. Skipping...
# Processing Record 233 of 616, vaitape.
# Processing Record 234 of 616, cidreira.
# Processing Record 235 of 616, tabialan.
# City not found. Skipping...
# Processing Record 236 of 616, talnakh.
# Processing Record 237 of 616, barcelos.
# Processing Record 238 of 616, uvalde.
# Processing Record 239 of 616, beloha.
# Processing Record 240 of 616, lashio.
# Processing Record 241 of 616, tasiilaq.
# Processing Record 242 of 616, kirkwall.
# Processing Record 243 of 616, naberera.
# Processing Record 244 of 616, severo-kurilsk.
# Processing Record 245 of 616, worland.
# Processing Record 246 of 616, edson.
# Processing Record 247 of 616, palmer.
# Processing Record 248 of 616, ahipara.
# Processing Record 249 of 616, egvekinot.
# Processing Record 250 of 616, norman wells.
# Processing Record 251 of 616, pisco.
# Processing Record 252 of 616, ngukurr.
# City not found. Skipping...
# Processing Record 253 of 616, bayburt.
# Processing Record 254 of 616, pomabamba.
# Processing Record 255 of 616, babanusah.
# City not found. Skipping...
# Processing Record 256 of 616, bargal.
# City not found. Skipping...
# Processing Record 257 of 616, kieta.
# Processing Record 258 of 616, khuzhir.
# Processing Record 259 of 616, portland.
# Processing Record 260 of 616, broome.
# Processing Record 261 of 616, ribeira grande.
# Processing Record 262 of 616, vila velha.
# Processing Record 263 of 616, silyanah.
# City not found. Skipping...
# Processing Record 264 of 616, cloquet.
# Processing Record 265 of 616, evensk.
# Processing Record 266 of 616, rio grande.
# Processing Record 267 of 616, sisophon.
# Processing Record 268 of 616, placido de castro.
# Processing Record 269 of 616, almora.
# Processing Record 270 of 616, okhotsk.
# Processing Record 271 of 616, lata.
# Processing Record 272 of 616, pelotas.
# Processing Record 273 of 616, tuatapere.
# Processing Record 274 of 616, golden.
# Processing Record 275 of 616, kazalinsk.
# City not found. Skipping...
# Processing Record 276 of 616, banda aceh.
# Processing Record 277 of 616, dibaya.
# City not found. Skipping...
# Processing Record 278 of 616, tala.
# Processing Record 279 of 616, samsun.
# Processing Record 280 of 616, tabriz.
# Processing Record 281 of 616, eureka.
# Processing Record 282 of 616, moscow.
# Processing Record 283 of 616, salta.
# Processing Record 284 of 616, guerrero negro.
# Processing Record 285 of 616, baherden.
# Processing Record 286 of 616, kavieng.
# Processing Record 287 of 616, bolungarvik.
# City not found. Skipping...
# Processing Record 288 of 616, kavaratti.
# Processing Record 289 of 616, tessalit.
# Processing Record 290 of 616, angra dos reis.
# Processing Record 291 of 616, aracruz.
# Processing Record 292 of 616, ajdabiya.
# Processing Record 293 of 616, yanchukan.
# City not found. Skipping...
# Processing Record 294 of 616, daru.
# Processing Record 295 of 616, qiongshan.
# Processing Record 296 of 616, upernavik.
# Processing Record 297 of 616, igarka.
# Processing Record 298 of 616, kismayo.
# City not found. Skipping...
# Processing Record 299 of 616, limon.
# Processing Record 300 of 616, sibolga.
# Processing Record 301 of 616, marzuq.
# Processing Record 302 of 616, sitka.
# Processing Record 303 of 616, mandali.
# Processing Record 304 of 616, chalchihuites.
# Processing Record 305 of 616, virginia beach.
# Processing Record 306 of 616, lemesos.
# City not found. Skipping...
# Processing Record 307 of 616, yar-sale.
# Processing Record 308 of 616, beruwala.
# Processing Record 309 of 616, warqla.
# City not found. Skipping...
# Processing Record 310 of 616, scarborough.
# Processing Record 311 of 616, roald.
# Processing Record 312 of 616, salekhard.
# Processing Record 313 of 616, djambala.
# Processing Record 314 of 616, constitucion.
# Processing Record 315 of 616, gravdal.
# Processing Record 316 of 616, san patricio.
# Processing Record 317 of 616, birao.
# Processing Record 318 of 616, ingham.
# Processing Record 319 of 616, sisimiut.
# Processing Record 320 of 616, hobyo.
# Processing Record 321 of 616, kaliua.
# Processing Record 322 of 616, grand gaube.
# Processing Record 323 of 616, neiva.
# Processing Record 324 of 616, taoudenni.
# Processing Record 325 of 616, karakose.
# City not found. Skipping...
# Processing Record 326 of 616, altamont.
# Processing Record 327 of 616, arman.
# Processing Record 328 of 616, chumikan.
# Processing Record 329 of 616, tarudant.
# City not found. Skipping...
# Processing Record 330 of 616, harrisonville.
# Processing Record 331 of 616, sahuaripa.
# Processing Record 332 of 616, magdagachi.
# Processing Record 333 of 616, moussoro.
# Processing Record 334 of 616, kharan.
# Processing Record 335 of 616, eenhana.
# Processing Record 336 of 616, lebu.
# Processing Record 337 of 616, nchelenge.
# Processing Record 338 of 616, of.
# City not found. Skipping...
# Processing Record 339 of 616, katsuura.
# Processing Record 340 of 616, norden.
# Processing Record 341 of 616, houma.
# Processing Record 342 of 616, yulara.
# Processing Record 343 of 616, akyab.
# City not found. Skipping...
# Processing Record 344 of 616, morondava.
# Processing Record 345 of 616, kang.
# Processing Record 346 of 616, salinopolis.
# Processing Record 347 of 616, rio branco.
# Processing Record 348 of 616, tupik.
# Processing Record 349 of 616, privolzhskiy.
# Processing Record 350 of 616, senanga.
# Processing Record 351 of 616, tumannyy.
# City not found. Skipping...
# Processing Record 352 of 616, umzimvubu.
# City not found. Skipping...
# Processing Record 353 of 616, poum.
# Processing Record 354 of 616, saurimo.
# Processing Record 355 of 616, zhangjiakou.
# Processing Record 356 of 616, paka.
# Processing Record 357 of 616, manokwari.
# Processing Record 358 of 616, burnie.
# Processing Record 359 of 616, kutum.
# Processing Record 360 of 616, auki.
# Processing Record 361 of 616, craigieburn.
# Processing Record 362 of 616, bima.
# Processing Record 363 of 616, tabou.
# Processing Record 364 of 616, uddevalla.
# Processing Record 365 of 616, boatlaname.
# City not found. Skipping...
# Processing Record 366 of 616, san vicente.
# Processing Record 367 of 616, ancud.
# Processing Record 368 of 616, artyk.
# City not found. Skipping...
# Processing Record 369 of 616, halalo.
# City not found. Skipping...
# Processing Record 370 of 616, obihiro.
# Processing Record 371 of 616, satipo.
# Processing Record 372 of 616, redcar.
# Processing Record 373 of 616, tadine.
# Processing Record 374 of 616, rudnichnyy.
# Processing Record 375 of 616, camacha.
# Processing Record 376 of 616, bo rai.
# Processing Record 377 of 616, vesyegonsk.
# Processing Record 378 of 616, changde.
# Processing Record 379 of 616, harper.
# Processing Record 380 of 616, sorong.
# Processing Record 381 of 616, palaikastron.
# Processing Record 382 of 616, pevek.
# Processing Record 383 of 616, nemuro.
# Processing Record 384 of 616, chastoozerye.
# City not found. Skipping...
# Processing Record 385 of 616, morehead.
# Processing Record 386 of 616, gallup.
# Processing Record 387 of 616, pringsewu.
# Processing Record 388 of 616, tres lagoas.
# City not found. Skipping...
# Processing Record 389 of 616, summerville.
# Processing Record 390 of 616, flinders.
# Processing Record 391 of 616, yerbogachen.
# Processing Record 392 of 616, noumea.
# Processing Record 393 of 616, esperance.
# Processing Record 394 of 616, alofi.
# Processing Record 395 of 616, sosnogorsk.
# Processing Record 396 of 616, mantua.
# Processing Record 397 of 616, ishigaki.
# Processing Record 398 of 616, dunedin.
# Processing Record 399 of 616, saint anthony.
# Processing Record 400 of 616, alugan.
# Processing Record 401 of 616, west bay.
# Processing Record 402 of 616, gat.
# Processing Record 403 of 616, sinkat.
# City not found. Skipping...
# Processing Record 404 of 616, tecoanapa.
# Processing Record 405 of 616, katiola.
# Processing Record 406 of 616, felidhoo.
# City not found. Skipping...
# Processing Record 407 of 616, dicabisagan.
# Processing Record 408 of 616, waingapu.
# Processing Record 409 of 616, fort nelson.
# Processing Record 410 of 616, high level.
# Processing Record 411 of 616, portree.
# Processing Record 412 of 616, killybegs.
# Processing Record 413 of 616, reconquista.
# Processing Record 414 of 616, jiddah.
# City not found. Skipping...
# Processing Record 415 of 616, yenagoa.
# Processing Record 416 of 616, yima.
# Processing Record 417 of 616, bay roberts.
# Processing Record 418 of 616, meyungs.
# City not found. Skipping...
# Processing Record 419 of 616, buenavista.
# Processing Record 420 of 616, kalmunai.
# Processing Record 421 of 616, plum.
# Processing Record 422 of 616, pacific grove.
# Processing Record 423 of 616, darhan.
# Processing Record 424 of 616, gopalpur.
# Processing Record 425 of 616, bochil.
# Processing Record 426 of 616, sakakah.
# City not found. Skipping...
# Processing Record 427 of 616, odessa.
# Processing Record 428 of 616, nazas.
# Processing Record 429 of 616, dwarka.
# Processing Record 430 of 616, taltal.
# Processing Record 431 of 616, vilhena.
# Processing Record 432 of 616, bereda.
# Processing Record 433 of 616, mocuba.
# Processing Record 434 of 616, jablah.
# Processing Record 435 of 616, coquimbo.
# Processing Record 436 of 616, svetlyy.
# City not found. Skipping...
# Processing Record 437 of 616, steinbach.
# Processing Record 438 of 616, kambove.
# Processing Record 439 of 616, geraldton.
# Processing Record 440 of 616, ouahigouya.
# Processing Record 441 of 616, jalingo.
# Processing Record 442 of 616, ambunti.
# Processing Record 443 of 616, mahebourg.
# Processing Record 444 of 616, strezhevoy.
# Processing Record 445 of 616, netrakona.
# Processing Record 446 of 616, srirampur.
# Processing Record 447 of 616, praia.
# Processing Record 448 of 616, batagay-alyta.
# Processing Record 449 of 616, comandau.
# Processing Record 450 of 616, samalaeulu.
# City not found. Skipping...
# Processing Record 451 of 616, oyem.
# Processing Record 452 of 616, camapua.
# Processing Record 453 of 616, muncar.
# Processing Record 454 of 616, hong gai.
# Processing Record 455 of 616, swanton.
# Processing Record 456 of 616, minot.
# Processing Record 457 of 616, tomatlan.
# Processing Record 458 of 616, the pas.
# Processing Record 459 of 616, balimo.
# City not found. Skipping...
# Processing Record 460 of 616, ambon.
# Processing Record 461 of 616, ahuimanu.
# Processing Record 462 of 616, mogadouro.
# Processing Record 463 of 616, vila franca do campo.
# Processing Record 464 of 616, dogondoutchi.
# Processing Record 465 of 616, baykit.
# Processing Record 466 of 616, warstein.
# Processing Record 467 of 616, maningrida.
# Processing Record 468 of 616, kelvington.
# Processing Record 469 of 616, alice springs.
# Processing Record 470 of 616, natal.
# Processing Record 471 of 616, sovetskiy.
# Processing Record 472 of 616, touros.
# Processing Record 473 of 616, tagusao.
# Processing Record 474 of 616, bayangol.
# Processing Record 475 of 616, kalengwa.
# Processing Record 476 of 616, aquin.
# Processing Record 477 of 616, honiara.
# Processing Record 478 of 616, coffs harbour.
# Processing Record 479 of 616, juneau.
# Processing Record 480 of 616, cabedelo.
# Processing Record 481 of 616, kumba.
# Processing Record 482 of 616, wollongong.
# Processing Record 483 of 616, corn island.
# Processing Record 484 of 616, bajo baudo.
# City not found. Skipping...
# Processing Record 485 of 616, chibuto.
# Processing Record 486 of 616, neiafu.
# Processing Record 487 of 616, meadow lake.
# Processing Record 488 of 616, looc.
# Processing Record 489 of 616, ouesso.
# Processing Record 490 of 616, chernyshevskiy.
# Processing Record 491 of 616, yuanping.
# Processing Record 492 of 616, pangnirtung.
# Processing Record 493 of 616, nioki.
# Processing Record 494 of 616, hofn.
# Processing Record 495 of 616, viedma.
# Processing Record 496 of 616, maragogi.
# Processing Record 497 of 616, tabas.
# Processing Record 498 of 616, am timan.
# Processing Record 499 of 616, attawapiskat.
# City not found. Skipping...
# Processing Record 500 of 616, mount gambier.
# Processing Record 501 of 616, boende.
# Processing Record 502 of 616, arvika.
# Processing Record 503 of 616, asau.
# City not found. Skipping...
# Processing Record 504 of 616, airai.
# Processing Record 505 of 616, lavrentiya.
# Processing Record 506 of 616, bulawayo.
# Processing Record 507 of 616, general roca.
# Processing Record 508 of 616, hampton.
# Processing Record 509 of 616, londoko.
# City not found. Skipping...
# Processing Record 510 of 616, mildura.
# Processing Record 511 of 616, bubaque.
# Processing Record 512 of 616, bontang.
# Processing Record 513 of 616, deputatskiy.
# Processing Record 514 of 616, shushtar.
# Processing Record 515 of 616, maltahohe.
# Processing Record 516 of 616, meulaboh.
# Processing Record 517 of 616, amapa.
# Processing Record 518 of 616, maghama.
# City not found. Skipping...
# Processing Record 519 of 616, shevchenkove.
# Processing Record 520 of 616, alakurtti.
# Processing Record 521 of 616, oranjestad.
# Processing Record 522 of 616, smithers.
# Processing Record 523 of 616, longkou.
# Processing Record 524 of 616, florianopolis.
# Processing Record 525 of 616, sterlibashevo.
# Processing Record 526 of 616, karratha.
# Processing Record 527 of 616, magnolia.
# Processing Record 528 of 616, parfino.
# Processing Record 529 of 616, huntington.
# Processing Record 530 of 616, kemijarvi.
# City not found. Skipping...
# Processing Record 531 of 616, safaga.
# City not found. Skipping...
# Processing Record 532 of 616, beringovskiy.
# Processing Record 533 of 616, tabuk.
# Processing Record 534 of 616, christchurch.
# Processing Record 535 of 616, mirnyy.
# Processing Record 536 of 616, rio tercero.
# Processing Record 537 of 616, lasa.
# Processing Record 538 of 616, krasnoselkup.
# City not found. Skipping...
# Processing Record 539 of 616, sayyan.
# Processing Record 540 of 616, bintulu.
# Processing Record 541 of 616, ulaangom.
# Processing Record 542 of 616, shillong.
# Processing Record 543 of 616, mitu.
# Processing Record 544 of 616, saint-francois.
# Processing Record 545 of 616, rio de jesus.
# Processing Record 546 of 616, casper.
# Processing Record 547 of 616, saint-leu.
# Processing Record 548 of 616, templin.
# Processing Record 549 of 616, plymouth.
# Processing Record 550 of 616, mirabad.
# Processing Record 551 of 616, uaua.
# Processing Record 552 of 616, thinadhoo.
# Processing Record 553 of 616, palu.
# Processing Record 554 of 616, saint pete beach.
# Processing Record 555 of 616, shirokiy.
# Processing Record 556 of 616, setermoen.
# Processing Record 557 of 616, manakara.
# Processing Record 558 of 616, naranjal.
# Processing Record 559 of 616, sanchursk.
# Processing Record 560 of 616, skole.
# Processing Record 561 of 616, kantunilkin.
# Processing Record 562 of 616, santa maria.
# Processing Record 563 of 616, warrington.
# Processing Record 564 of 616, peleduy.
# Processing Record 565 of 616, tripoli.
# Processing Record 566 of 616, senekal.
# Processing Record 567 of 616, alenquer.
# Processing Record 568 of 616, awjilah.
# Processing Record 569 of 616, sompeta.
# Processing Record 570 of 616, ampanihy.
# Processing Record 571 of 616, constantine.
# Processing Record 572 of 616, nago.
# Processing Record 573 of 616, matara.
# Processing Record 574 of 616, inhambane.
# Processing Record 575 of 616, ketchikan.
# Processing Record 576 of 616, yen bai.
# Processing Record 577 of 616, baruun-urt.
# Processing Record 578 of 616, sarangani.
# Processing Record 579 of 616, calabozo.
# Processing Record 580 of 616, puerto escondido.
# Processing Record 581 of 616, dossor.
# Processing Record 582 of 616, dubbo.
# Processing Record 583 of 616, capitan bado.
# Processing Record 584 of 616, marsh harbour.
# Processing Record 585 of 616, whitehorse.
# Processing Record 586 of 616, half moon bay.
# Processing Record 587 of 616, mackay.
# Processing Record 588 of 616, mweka.
# Processing Record 589 of 616, dingle.
# Processing Record 590 of 616, villaviciosa.
# Processing Record 591 of 616, alyangula.
# Processing Record 592 of 616, geresk.
# City not found. Skipping...
# Processing Record 593 of 616, la paz.
# Processing Record 594 of 616, san carlos de bariloche.
# Processing Record 595 of 616, mancio lima.
# City not found. Skipping...
# Processing Record 596 of 616, abalak.
# Processing Record 597 of 616, anito.
# Processing Record 598 of 616, rawson.
# Processing Record 599 of 616, praia da vitoria.
# Processing Record 600 of 616, kununurra.
# Processing Record 601 of 616, imola.
# Processing Record 602 of 616, toliary.
# City not found. Skipping...
# Processing Record 603 of 616, seoul.
# Processing Record 604 of 616, cairns.
# Processing Record 605 of 616, southbridge.
# Processing Record 606 of 616, areka.
# Processing Record 607 of 616, kailua.
# Processing Record 608 of 616, kaniama.
# Processing Record 609 of 616, dalbandin.
# Processing Record 610 of 616, falealupo.
# City not found. Skipping...
# Processing Record 611 of 616, rapid valley.
# Processing Record 612 of 616, vilyuysk.
# Processing Record 613 of 616, luderitz.
# Processing Record 614 of 616, lichinga.
# Processing Record 615 of 616, sharkan.
# Processing Record 616 of 616, brae.

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
#create a Data Frame with the previous created arrays
weather_data = pd.DataFrame({"City":City,
                             "Country":Country,
                             "Latitude":Lat,
                             "Longitude":Lng,
                             "Date":Date,
                             "Cloudiness":Cloudiness,
                             "Humidity":Humidity,
                             "Max Temp":Max_Temp,
                             "Wind Speed":Wind_Speed})

# Export file as a CSV, without the Pandas index, but with the header
weather_data.to_csv("Output Data/Weather Data.csv", index=False, header=True)

# Mapping lets you format an entire DataFrame
file = "Output Data/Weather Data.csv"
weather_df = pd.read_csv(file)
print(weather_df.count())
weather_df.head()
# Out:
# City          547
# Country       543
# Latitude      547
# Longitude     547
# Date          547
# Cloudiness    547
# Humidity      547
# Max Temp      547
# Wind Speed    547
# dtype: int64
#                  City Country  Latitude  Longitude        Date  Cloudiness  \
# 0  Comodoro Rivadavia      AR    -45.87     -67.48  1549144800           0
# 1              Avarua      CK    -21.21    -159.78  1549144800          75
# 2            Hermanus      ZA    -34.42      19.24  1549146355          76
# 3      Leningradskaya      RU     46.32      39.39  1549146356          92
# 4             Ushuaia      AR    -54.81     -68.31  1549144800          75
#
#    Humidity  Max Temp  Wind Speed
# 0        38     73.40       12.75
# 1        78     82.40        4.70
# 2        96     63.24        2.80
# 3       100     38.94        6.49
# 4        67     59.00       20.80

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
plt.scatter(weather_df['Latitude'], weather_df['Max Temp'], marker="o", facecolors="blue", edgecolors="black",
            s=50, alpha=0.5)


plt.xlabel("Latitude")
plt.ylabel("Max Tempersture (F)")
plt.title("City Latitude vs. Max Temperature")
plt.grid()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
plt.scatter(weather_df['Latitude'], weather_df['Humidity'], marker="o", facecolors="blue", edgecolors="black",
            s=50, alpha=0.5)


plt.xlabel("Latitude")
plt.ylabel("Humididty (%)")
plt.title("City Latitude vs. Humidity")
plt.grid()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
plt.scatter(weather_df['Latitude'], weather_df['Cloudiness'], marker="o", facecolors="blue", edgecolors="black",
            s=50, alpha=0.5)


plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.title("City Latitude vs. Cloudiness")
plt.grid()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
plt.scatter(weather_df['Latitude'], weather_df['Wind Speed'], marker="o", facecolors="blue", edgecolors="black",
            s=50, alpha=0.5)


plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.title("City Latitude vs. Wind Speed")
plt.grid()
