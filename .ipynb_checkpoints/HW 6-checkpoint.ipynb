# %% [markdown]
# # WeatherPy
# ----
#
# ### Analysis
# * The weather appears to get significantly colder as the Latitude increases while a comparable negative Latitue does not see the same decrease in Temperature
# * There appears to be no strong relationship between Latitude and Humidity but Humidity shares the same relationship as Temperature to Latitude where the negative Latitudes experience less of a dreacrease in Humidity than the positive Latitudes do
# * There doesn't appear to be a relationship between Wind Speed or Cloudiness and Latitude, however there seems to be one city that is experiencing some extreame weather currently with Wind Speeds well over 150 mph.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import json

# Import API key
from config import api_keys

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 582

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
City = []
Country = []
Lat = []
Lng = []
Date = []
Cloudiness = []
Humidity = []
Max_Temp = [] 
Wind_Speed = []

base_url = 'https://api.openweathermap.org/data/2.5/weather?q={0}&appid={1}&units=imperial'

counter=1

#loop through cities to request the weather data and store each parameter in an array
for i in range(len(cities)):
    
    target_city = cities[i]
    url = base_url.format(target_city,api_keys)

    response = requests.get(url).json()

    try:
        print("Processing Record " + str(counter) + " of " + str(len(cities)) + ", "+ str(target_city) + ".")
        
        City.append(response['name'])
        Country.append(response['sys']['country'])
        Lat.append(response['coord']['lat'])
        Lng.append(response['coord']['lon'])
        Date.append(response['dt'])
        Cloudiness.append(response['clouds']['all'])
        Humidity.append(response['main']['humidity'])
        Max_Temp.append(response['main']['temp_max'])
        Wind_Speed.append(response['wind']['speed'])
        
    except (KeyError, IndexError):
        print("City not found. Skipping...")
        
    counter = counter+1
# Out:
# Processing Record 1 of 582, rikitea.
# Processing Record 2 of 582, mahebourg.
# Processing Record 3 of 582, castro.
# Processing Record 4 of 582, atuona.
# Processing Record 5 of 582, ponta do sol.
# Processing Record 6 of 582, arraial do cabo.
# Processing Record 7 of 582, talnakh.
# Processing Record 8 of 582, bolshoy tsaryn.
# City not found. Skipping...
# Processing Record 9 of 582, labytnangi.
# Processing Record 10 of 582, barentsburg.
# City not found. Skipping...
# Processing Record 11 of 582, port hedland.
# Processing Record 12 of 582, taolanaro.
# City not found. Skipping...
# Processing Record 13 of 582, umm lajj.
# Processing Record 14 of 582, berezovyy.
# Processing Record 15 of 582, vilhena.
# Processing Record 16 of 582, carnarvon.
# Processing Record 17 of 582, saint-philippe.
# Processing Record 18 of 582, eyl.
# Processing Record 19 of 582, victoria.
# Processing Record 20 of 582, hermanus.
# Processing Record 21 of 582, natal.
# Processing Record 22 of 582, beloha.
# Processing Record 23 of 582, bluff.
# Processing Record 24 of 582, tsienyane.
# City not found. Skipping...
# Processing Record 25 of 582, mataura.
# Processing Record 26 of 582, jamestown.
# Processing Record 27 of 582, clyde river.
# Processing Record 28 of 582, chokurdakh.
# Processing Record 29 of 582, batagay-alyta.
# Processing Record 30 of 582, ushuaia.
# Processing Record 31 of 582, baturyn.
# Processing Record 32 of 582, east london.
# Processing Record 33 of 582, komsomolskiy.
# Processing Record 34 of 582, upernavik.
# Processing Record 35 of 582, nikolskoye.
# Processing Record 36 of 582, ribeira grande.
# Processing Record 37 of 582, bredasdorp.
# Processing Record 38 of 582, angoram.
# Processing Record 39 of 582, khani.
# Processing Record 40 of 582, longyearbyen.
# Processing Record 41 of 582, tiarei.
# Processing Record 42 of 582, bac lieu.
# City not found. Skipping...
# Processing Record 43 of 582, baruun-urt.
# Processing Record 44 of 582, viedma.
# Processing Record 45 of 582, makakilo city.
# Processing Record 46 of 582, karaul.
# City not found. Skipping...
# Processing Record 47 of 582, aklavik.
# Processing Record 48 of 582, mys shmidta.
# City not found. Skipping...
# Processing Record 49 of 582, attawapiskat.
# City not found. Skipping...
# Processing Record 50 of 582, narsaq.
# Processing Record 51 of 582, geraldton.
# Processing Record 52 of 582, hobyo.
# Processing Record 53 of 582, wonthaggi.
# Processing Record 54 of 582, tuatapere.
# Processing Record 55 of 582, kiunga.
# Processing Record 56 of 582, hobart.
# Processing Record 57 of 582, sao miguel do araguaia.
# Processing Record 58 of 582, fairbanks.
# Processing Record 59 of 582, puerto baquerizo moreno.
# Processing Record 60 of 582, provideniya.
# Processing Record 61 of 582, mersin.
# Processing Record 62 of 582, rocha.
# Processing Record 63 of 582, bambous virieux.
# Processing Record 64 of 582, belushya guba.
# City not found. Skipping...
# Processing Record 65 of 582, asau.
# City not found. Skipping...
# Processing Record 66 of 582, busselton.
# Processing Record 67 of 582, punta arenas.
# Processing Record 68 of 582, georgetown.
# Processing Record 69 of 582, thompson.
# Processing Record 70 of 582, gizo.
# Processing Record 71 of 582, sinnamary.
# Processing Record 72 of 582, khatanga.
# Processing Record 73 of 582, ossora.
# Processing Record 74 of 582, deniliquin.
# Processing Record 75 of 582, dakar.
# Processing Record 76 of 582, new norfolk.
# Processing Record 77 of 582, pangoa.
# Processing Record 78 of 582, port macquarie.
# Processing Record 79 of 582, padang.
# Processing Record 80 of 582, frontera comalapa.
# Processing Record 81 of 582, nenjiang.
# Processing Record 82 of 582, kaitangata.
# Processing Record 83 of 582, muros.
# Processing Record 84 of 582, esperance.
# Processing Record 85 of 582, taoudenni.
# Processing Record 86 of 582, beian.
# Processing Record 87 of 582, hilo.
# Processing Record 88 of 582, torbay.
# Processing Record 89 of 582, yulara.
# Processing Record 90 of 582, bethel.
# Processing Record 91 of 582, alofi.
# Processing Record 92 of 582, warmbad.
# Processing Record 93 of 582, kodiak.
# Processing Record 94 of 582, kapaa.
# Processing Record 95 of 582, shimoda.
# Processing Record 96 of 582, albany.
# Processing Record 97 of 582, odweyne.
# City not found. Skipping...
# Processing Record 98 of 582, sao filipe.
# Processing Record 99 of 582, valley city.
# Processing Record 100 of 582, ancud.
# Processing Record 101 of 582, norman wells.
# Processing Record 102 of 582, tanout.
# Processing Record 103 of 582, rezekne.
# Processing Record 104 of 582, yian.
# City not found. Skipping...
# Processing Record 105 of 582, pevek.
# Processing Record 106 of 582, beruwala.
# Processing Record 107 of 582, effingham.
# Processing Record 108 of 582, hasaki.
# Processing Record 109 of 582, uirauna.
# Processing Record 110 of 582, yellowknife.
# Processing Record 111 of 582, lethem.
# Processing Record 112 of 582, hithadhoo.
# Processing Record 113 of 582, port lincoln.
# Processing Record 114 of 582, qui nhon.
# City not found. Skipping...
# Processing Record 115 of 582, pontianak.
# Processing Record 116 of 582, grand river south east.
# City not found. Skipping...
# Processing Record 117 of 582, oktyabrskoye.
# Processing Record 118 of 582, honiara.
# Processing Record 119 of 582, elk.
# Processing Record 120 of 582, pisco.
# Processing Record 121 of 582, vanavara.
# Processing Record 122 of 582, barrow.
# Processing Record 123 of 582, orlik.
# Processing Record 124 of 582, illoqqortoormiut.
# City not found. Skipping...
# Processing Record 125 of 582, tasiilaq.
# Processing Record 126 of 582, gua musang.
# Processing Record 127 of 582, lompoc.
# Processing Record 128 of 582, nizhneyansk.
# City not found. Skipping...
# Processing Record 129 of 582, katsuura.
# Processing Record 130 of 582, tsihombe.
# City not found. Skipping...
# Processing Record 131 of 582, luena.
# Processing Record 132 of 582, marsh harbour.
# Processing Record 133 of 582, rio tercero.
# Processing Record 134 of 582, qaanaaq.
# Processing Record 135 of 582, huicungo.
# Processing Record 136 of 582, dibulla.
# Processing Record 137 of 582, mogocha.
# Processing Record 138 of 582, cabo san lucas.
# Processing Record 139 of 582, cape town.
# Processing Record 140 of 582, dimapur.
# Processing Record 141 of 582, pacific grove.
# Processing Record 142 of 582, sur.
# Processing Record 143 of 582, suhut.
# Processing Record 144 of 582, adrar.
# Processing Record 145 of 582, severo-kurilsk.
# Processing Record 146 of 582, port alfred.
# Processing Record 147 of 582, jumla.
# Processing Record 148 of 582, oksfjord.
# Processing Record 149 of 582, sola.
# Processing Record 150 of 582, iqaluit.
# Processing Record 151 of 582, derzhavinsk.
# Processing Record 152 of 582, kautokeino.
# Processing Record 153 of 582, kahului.
# Processing Record 154 of 582, makokou.
# Processing Record 155 of 582, vanimo.
# Processing Record 156 of 582, birin.
# Processing Record 157 of 582, labrea.
# City not found. Skipping...
# Processing Record 158 of 582, bajo baudo.
# City not found. Skipping...
# Processing Record 159 of 582, lorengau.
# Processing Record 160 of 582, montauban.
# Processing Record 161 of 582, samarinda.
# Processing Record 162 of 582, shelburne.
# Processing Record 163 of 582, deming.
# Processing Record 164 of 582, ambon.
# Processing Record 165 of 582, shingu.
# Processing Record 166 of 582, dongsheng.
# Processing Record 167 of 582, vaini.
# Processing Record 168 of 582, mangrol.
# Processing Record 169 of 582, gorno-altaysk.
# Processing Record 170 of 582, airai.
# Processing Record 171 of 582, cidreira.
# Processing Record 172 of 582, mount isa.
# Processing Record 173 of 582, mareeba.
# Processing Record 174 of 582, koumac.
# Processing Record 175 of 582, belmonte.
# Processing Record 176 of 582, lavrentiya.
# Processing Record 177 of 582, nurota.
# Processing Record 178 of 582, waingapu.
# Processing Record 179 of 582, vaitupu.
# City not found. Skipping...
# Processing Record 180 of 582, mizdah.
# Processing Record 181 of 582, voyinka.
# Processing Record 182 of 582, tatarsk.
# Processing Record 183 of 582, codrington.
# Processing Record 184 of 582, korla.
# City not found. Skipping...
# Processing Record 185 of 582, myanaung.
# Processing Record 186 of 582, anadyr.
# Processing Record 187 of 582, tuktoyaktuk.
# Processing Record 188 of 582, lagoa.
# Processing Record 189 of 582, kavaratti.
# Processing Record 190 of 582, ambilobe.
# Processing Record 191 of 582, deputatskiy.
# Processing Record 192 of 582, almendralejo.
# Processing Record 193 of 582, severobaykalsk.
# Processing Record 194 of 582, samarai.
# Processing Record 195 of 582, manakara.
# Processing Record 196 of 582, arrecife.
# City not found. Skipping...
# Processing Record 197 of 582, butaritari.
# Processing Record 198 of 582, amderma.
# City not found. Skipping...
# Processing Record 199 of 582, jiaocheng.
# Processing Record 200 of 582, vardo.
# Processing Record 201 of 582, sorvag.
# City not found. Skipping...
# Processing Record 202 of 582, harindanga.
# Processing Record 203 of 582, mehamn.
# Processing Record 204 of 582, puerto escondido.
# Processing Record 205 of 582, jiaojiang.
# City not found. Skipping...
# Processing Record 206 of 582, tumannyy.
# City not found. Skipping...
# Processing Record 207 of 582, grand gaube.
# Processing Record 208 of 582, tazovskiy.
# Processing Record 209 of 582, muli.
# Processing Record 210 of 582, poronaysk.
# Processing Record 211 of 582, phalodi.
# Processing Record 212 of 582, abnub.
# Processing Record 213 of 582, maraba.
# Processing Record 214 of 582, wahran.
# City not found. Skipping...
# Processing Record 215 of 582, saint-pierre.
# Processing Record 216 of 582, bagdarin.
# Processing Record 217 of 582, puerto ayora.
# Processing Record 218 of 582, emerald.
# Processing Record 219 of 582, solnechnyy.
# Processing Record 220 of 582, kontagora.
# Processing Record 221 of 582, cherskiy.
# Processing Record 222 of 582, neiafu.
# Processing Record 223 of 582, faya.
# Processing Record 224 of 582, san patricio.
# Processing Record 225 of 582, port elizabeth.
# Processing Record 226 of 582, huarmey.
# Processing Record 227 of 582, jalu.
# Processing Record 228 of 582, saskylakh.
# Processing Record 229 of 582, bolobo.
# Processing Record 230 of 582, ouro preto do oeste.
# Processing Record 231 of 582, mazarron.
# Processing Record 232 of 582, grindavik.
# Processing Record 233 of 582, najran.
# Processing Record 234 of 582, nusaybin.
# Processing Record 235 of 582, kaihua.
# Processing Record 236 of 582, eureka.
# Processing Record 237 of 582, nhamunda.
# Processing Record 238 of 582, portland.
# Processing Record 239 of 582, tshikapa.
# Processing Record 240 of 582, oum hadjer.
# Processing Record 241 of 582, olafsvik.
# City not found. Skipping...
# Processing Record 242 of 582, bilma.
# Processing Record 243 of 582, saint-georges.
# Processing Record 244 of 582, sosnovo-ozerskoye.
# Processing Record 245 of 582, hvolsvollur.
# City not found. Skipping...
# Processing Record 246 of 582, barra do garcas.
# Processing Record 247 of 582, dikson.
# Processing Record 248 of 582, martin.
# Processing Record 249 of 582, lensk.
# Processing Record 250 of 582, ilulissat.
# Processing Record 251 of 582, cartagena del chaira.
# Processing Record 252 of 582, marsaxlokk.
# Processing Record 253 of 582, avarua.
# Processing Record 254 of 582, gurgan.
# City not found. Skipping...
# Processing Record 255 of 582, niquero.
# Processing Record 256 of 582, dubrovka.
# Processing Record 257 of 582, luwuk.
# Processing Record 258 of 582, san jose.
# Processing Record 259 of 582, wuning.
# Processing Record 260 of 582, warqla.
# City not found. Skipping...
# Processing Record 261 of 582, chuy.
# Processing Record 262 of 582, coahuayana.
# Processing Record 263 of 582, ahipara.
# Processing Record 264 of 582, leninsk-kuznetskiy.
# Processing Record 265 of 582, abiy adi.
# City not found. Skipping...
# Processing Record 266 of 582, victor harbor.
# Processing Record 267 of 582, marshfield.
# Processing Record 268 of 582, saryagash.
# Processing Record 269 of 582, princeton.
# Processing Record 270 of 582, utiroa.
# City not found. Skipping...
# Processing Record 271 of 582, sentyabrskiy.
# City not found. Skipping...
# Processing Record 272 of 582, esmeraldas.
# Processing Record 273 of 582, marataizes.
# Processing Record 274 of 582, hokitika.
# Processing Record 275 of 582, hamilton.
# Processing Record 276 of 582, bykovo.
# Processing Record 277 of 582, mehriz.
# Processing Record 278 of 582, ewa beach.
# Processing Record 279 of 582, harper.
# Processing Record 280 of 582, huilong.
# Processing Record 281 of 582, erdenet.
# Processing Record 282 of 582, kotelnikovo.
# Processing Record 283 of 582, san quintin.
# Processing Record 284 of 582, barcelona.
# Processing Record 285 of 582, los llanos de aridane.
# Processing Record 286 of 582, saint george.
# Processing Record 287 of 582, henderson.
# Processing Record 288 of 582, dire dawa.
# Processing Record 289 of 582, lazaro cardenas.
# Processing Record 290 of 582, bandarbeyla.
# Processing Record 291 of 582, ayan.
# Processing Record 292 of 582, vagur.
# Processing Record 293 of 582, tilichiki.
# Processing Record 294 of 582, bocas del toro.
# Processing Record 295 of 582, ulaangom.
# Processing Record 296 of 582, laiagam.
# City not found. Skipping...
# Processing Record 297 of 582, celestun.
# Processing Record 298 of 582, salalah.
# Processing Record 299 of 582, tarakan.
# Processing Record 300 of 582, jian.
# Processing Record 301 of 582, temascalcingo.
# Processing Record 302 of 582, sao sepe.
# Processing Record 303 of 582, babanusah.
# City not found. Skipping...
# Processing Record 304 of 582, port hardy.
# Processing Record 305 of 582, agadez.
# Processing Record 306 of 582, tiksi.
# Processing Record 307 of 582, honolulu.
# Processing Record 308 of 582, samalaeulu.
# City not found. Skipping...
# Processing Record 309 of 582, kaeo.
# Processing Record 310 of 582, bealanana.
# Processing Record 311 of 582, rantepao.
# Processing Record 312 of 582, umzimvubu.
# City not found. Skipping...
# Processing Record 313 of 582, sitka.
# Processing Record 314 of 582, sibu.
# Processing Record 315 of 582, namibe.
# Processing Record 316 of 582, tambovka.
# Processing Record 317 of 582, vuktyl.
# Processing Record 318 of 582, samusu.
# City not found. Skipping...
# Processing Record 319 of 582, college.
# Processing Record 320 of 582, campbellsville.
# Processing Record 321 of 582, juruti.
# Processing Record 322 of 582, fremont.
# Processing Record 323 of 582, tokmak.
# Processing Record 324 of 582, santa ines.
# Processing Record 325 of 582, errol.
# Processing Record 326 of 582, pedernales.
# Processing Record 327 of 582, haines junction.
# Processing Record 328 of 582, kathu.
# Processing Record 329 of 582, calamar.
# Processing Record 330 of 582, rio grande.
# Processing Record 331 of 582, gazanjyk.
# Processing Record 332 of 582, minas novas.
# Processing Record 333 of 582, fortuna.
# Processing Record 334 of 582, coihaique.
# Processing Record 335 of 582, osakarovka.
# Processing Record 336 of 582, gat.
# Processing Record 337 of 582, kruisfontein.
# Processing Record 338 of 582, bubaque.
# Processing Record 339 of 582, cururupu.
# Processing Record 340 of 582, ruidoso.
# Processing Record 341 of 582, semirom.
# Processing Record 342 of 582, paratinga.
# Processing Record 343 of 582, varhaug.
# Processing Record 344 of 582, tecpan.
# Processing Record 345 of 582, nakhon nayok.
# Processing Record 346 of 582, dudinka.
# Processing Record 347 of 582, santa cruz del sur.
# Processing Record 348 of 582, cantaura.
# Processing Record 349 of 582, tikamgarh.
# Processing Record 350 of 582, flinders.
# Processing Record 351 of 582, sabang.
# Processing Record 352 of 582, ngunguru.
# Processing Record 353 of 582, poso.
# Processing Record 354 of 582, elizabeth city.
# Processing Record 355 of 582, margate.
# Processing Record 356 of 582, tiznit.
# Processing Record 357 of 582, raudeberg.
# Processing Record 358 of 582, bani.
# Processing Record 359 of 582, comodoro rivadavia.
# Processing Record 360 of 582, yarada.
# Processing Record 361 of 582, juneau.
# Processing Record 362 of 582, uzhur-4.
# City not found. Skipping...
# Processing Record 363 of 582, karratha.
# Processing Record 364 of 582, kaseda.
# Processing Record 365 of 582, puri.
# Processing Record 366 of 582, vostok.
# Processing Record 367 of 582, norman.
# Processing Record 368 of 582, magdalena.
# Processing Record 369 of 582, monroe.
# Processing Record 370 of 582, leningradskiy.
# Processing Record 371 of 582, castanos.
# Processing Record 372 of 582, ardalstangen.
# Processing Record 373 of 582, igbo ora.
# Processing Record 374 of 582, abha.
# Processing Record 375 of 582, boende.
# Processing Record 376 of 582, marrakesh.
# Processing Record 377 of 582, tuggurt.
# City not found. Skipping...
# Processing Record 378 of 582, praia da vitoria.
# Processing Record 379 of 582, opuwo.
# Processing Record 380 of 582, nyurba.
# Processing Record 381 of 582, vila franca do campo.
# Processing Record 382 of 582, palora.
# Processing Record 383 of 582, broome.
# Processing Record 384 of 582, tabuk.
# Processing Record 385 of 582, banda aceh.
# Processing Record 386 of 582, general pico.
# Processing Record 387 of 582, guanica.
# Processing Record 388 of 582, latung.
# Processing Record 389 of 582, pahrump.
# Processing Record 390 of 582, waspan.
# City not found. Skipping...
# Processing Record 391 of 582, tuy hoa.
# Processing Record 392 of 582, canico.
# Processing Record 393 of 582, kuytun.
# Processing Record 394 of 582, gibara.
# Processing Record 395 of 582, chapais.
# Processing Record 396 of 582, bathsheba.
# Processing Record 397 of 582, nha trang.
# Processing Record 398 of 582, aldergrove.
# Processing Record 399 of 582, bogande.
# Processing Record 400 of 582, hays.
# Processing Record 401 of 582, isangel.
# Processing Record 402 of 582, hangu.
# Processing Record 403 of 582, sangar.
# Processing Record 404 of 582, tevaitoa.
# Processing Record 405 of 582, bengkulu.
# City not found. Skipping...
# Processing Record 406 of 582, nome.
# Processing Record 407 of 582, lebu.
# Processing Record 408 of 582, pangnirtung.
# Processing Record 409 of 582, roald.
# Processing Record 410 of 582, te anau.
# Processing Record 411 of 582, elat.
# Processing Record 412 of 582, necochea.
# Processing Record 413 of 582, bargal.
# City not found. Skipping...
# Processing Record 414 of 582, thivai.
# Processing Record 415 of 582, atar.
# Processing Record 416 of 582, praia.
# Processing Record 417 of 582, itoman.
# Processing Record 418 of 582, dhidhdhoo.
# Processing Record 419 of 582, vad.
# Processing Record 420 of 582, dana point.
# Processing Record 421 of 582, lubango.
# Processing Record 422 of 582, wangaratta.
# Processing Record 423 of 582, klaksvik.
# Processing Record 424 of 582, myitkyina.
# Processing Record 425 of 582, buraydah.
# Processing Record 426 of 582, saleaula.
# City not found. Skipping...
# Processing Record 427 of 582, quelimane.
# Processing Record 428 of 582, yashkul.
# Processing Record 429 of 582, kulhudhuffushi.
# Processing Record 430 of 582, disna.
# City not found. Skipping...
# Processing Record 431 of 582, borogontsy.
# Processing Record 432 of 582, sidi ali.
# Processing Record 433 of 582, mar del plata.
# Processing Record 434 of 582, agva.
# City not found. Skipping...
# Processing Record 435 of 582, lerwick.
# Processing Record 436 of 582, marquette.
# Processing Record 437 of 582, marfino.
# Processing Record 438 of 582, sungairaya.
# Processing Record 439 of 582, saint-joseph.
# Processing Record 440 of 582, fasa.
# Processing Record 441 of 582, bundaberg.
# Processing Record 442 of 582, rio gallegos.
# Processing Record 443 of 582, outjo.
# Processing Record 444 of 582, ayagoz.
# Processing Record 445 of 582, bazarnyye mataki.
# Processing Record 446 of 582, uk.
# City not found. Skipping...
# Processing Record 447 of 582, hailar.
# Processing Record 448 of 582, marzuq.
# Processing Record 449 of 582, chernihiv.
# Processing Record 450 of 582, ruatoria.
# City not found. Skipping...
# Processing Record 451 of 582, san martin.
# Processing Record 452 of 582, half moon bay.
# Processing Record 453 of 582, lakes entrance.
# Processing Record 454 of 582, baker city.
# Processing Record 455 of 582, conde.
# Processing Record 456 of 582, pasan.
# Processing Record 457 of 582, faanui.
# Processing Record 458 of 582, gold coast.
# Processing Record 459 of 582, ifakara.
# Processing Record 460 of 582, coquimbo.
# Processing Record 461 of 582, dunedin.
# Processing Record 462 of 582, nangong.
# Processing Record 463 of 582, sechura.
# Processing Record 464 of 582, wau.
# City not found. Skipping...
# Processing Record 465 of 582, berlevag.
# Processing Record 466 of 582, souillac.
# Processing Record 467 of 582, sisimiut.
# Processing Record 468 of 582, imbituba.
# Processing Record 469 of 582, pochutla.
# Processing Record 470 of 582, san ignacio.
# Processing Record 471 of 582, mitsamiouli.
# Processing Record 472 of 582, manching.
# Processing Record 473 of 582, havelock.
# Processing Record 474 of 582, meyungs.
# City not found. Skipping...
# Processing Record 475 of 582, saint anthony.
# Processing Record 476 of 582, swan river.
# Processing Record 477 of 582, mandurah.
# Processing Record 478 of 582, carutapera.
# Processing Record 479 of 582, narsipatnam.
# Processing Record 480 of 582, sobolevo.
# Processing Record 481 of 582, meulaboh.
# Processing Record 482 of 582, maragogi.
# Processing Record 483 of 582, ixtapa.
# Processing Record 484 of 582, bawku.
# Processing Record 485 of 582, oxford.
# Processing Record 486 of 582, sueyoshi.
# Processing Record 487 of 582, mendahara.
# City not found. Skipping...
# Processing Record 488 of 582, hastings.
# Processing Record 489 of 582, beringovskiy.
# Processing Record 490 of 582, novyy urengoy.
# Processing Record 491 of 582, karauzyak.
# City not found. Skipping...
# Processing Record 492 of 582, ploemeur.
# Processing Record 493 of 582, sao francisco do sul.
# Processing Record 494 of 582, mandal.
# Processing Record 495 of 582, rangpo.
# Processing Record 496 of 582, witrivier.
# City not found. Skipping...
# Processing Record 497 of 582, port augusta.
# Processing Record 498 of 582, la ronge.
# Processing Record 499 of 582, kalmunai.
# Processing Record 500 of 582, naze.
# Processing Record 501 of 582, villa constitucion.
# Processing Record 502 of 582, boysun.
# Processing Record 503 of 582, riyadh.
# Processing Record 504 of 582, sillod.
# Processing Record 505 of 582, ashcroft.
# Processing Record 506 of 582, nagato.
# Processing Record 507 of 582, nouakchott.
# Processing Record 508 of 582, lalomanu.
# City not found. Skipping...
# Processing Record 509 of 582, gamba.
# Processing Record 510 of 582, kalakamati.
# Processing Record 511 of 582, westport.
# Processing Record 512 of 582, cottbus.
# Processing Record 513 of 582, vila verde.
# Processing Record 514 of 582, nayoro.
# Processing Record 515 of 582, russell.
# Processing Record 516 of 582, roebourne.
# Processing Record 517 of 582, bondo.
# Processing Record 518 of 582, buckie.
# Processing Record 519 of 582, tucumcari.
# Processing Record 520 of 582, anloga.
# Processing Record 521 of 582, dingle.
# Processing Record 522 of 582, evanston.
# Processing Record 523 of 582, semnan.
# Processing Record 524 of 582, verkhoshizhemye.
# Processing Record 525 of 582, bara.
# Processing Record 526 of 582, kushiro.
# Processing Record 527 of 582, laguna.
# Processing Record 528 of 582, atambua.
# Processing Record 529 of 582, kavieng.
# Processing Record 530 of 582, sunnyside.
# Processing Record 531 of 582, malanje.
# Processing Record 532 of 582, ust-tsilma.
# Processing Record 533 of 582, maniitsoq.
# Processing Record 534 of 582, grand forks.
# Processing Record 535 of 582, halalo.
# City not found. Skipping...
# Processing Record 536 of 582, pokaran.
# Processing Record 537 of 582, pathein.
# Processing Record 538 of 582, agua dulce.
# Processing Record 539 of 582, mahajanga.
# Processing Record 540 of 582, san cristobal.
# Processing Record 541 of 582, zaozerne.
# Processing Record 542 of 582, piranhas.
# Processing Record 543 of 582, phrai bung.
# City not found. Skipping...
# Processing Record 544 of 582, kudat.
# Processing Record 545 of 582, evans.
# Processing Record 546 of 582, bloemfontein.
# Processing Record 547 of 582, riviere-au-renard.
# Processing Record 548 of 582, cam ranh.
# Processing Record 549 of 582, saldanha.
# Processing Record 550 of 582, anamur.
# Processing Record 551 of 582, vilyuysk.
# Processing Record 552 of 582, black diamond.
# Processing Record 553 of 582, san jeronimo.
# Processing Record 554 of 582, tashtagol.
# Processing Record 555 of 582, chicama.
# Processing Record 556 of 582, muroto.
# Processing Record 557 of 582, breytovo.
# Processing Record 558 of 582, naberera.
# Processing Record 559 of 582, guilin.
# Processing Record 560 of 582, nizhniy kuranakh.
# Processing Record 561 of 582, lukang.
# Processing Record 562 of 582, hovd.
# Processing Record 563 of 582, cockburn town.
# Processing Record 564 of 582, mwinilunga.
# Processing Record 565 of 582, labuan.
# Processing Record 566 of 582, nioro.
# Processing Record 567 of 582, trairi.
# Processing Record 568 of 582, desaguadero.
# Processing Record 569 of 582, nantucket.
# Processing Record 570 of 582, zyryanka.
# Processing Record 571 of 582, durango.
# Processing Record 572 of 582, eseka.
# Processing Record 573 of 582, revelstoke.
# Processing Record 574 of 582, sar-e pul.
# Processing Record 575 of 582, tegh.
# Processing Record 576 of 582, cap-aux-meules.
# Processing Record 577 of 582, jawhar.
# Processing Record 578 of 582, fevralsk.
# City not found. Skipping...
# Processing Record 579 of 582, langres.
# Processing Record 580 of 582, glenwood springs.
# Processing Record 581 of 582, kiama.
# Processing Record 582 of 582, upata.

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
#create a Data Frame with the previous created arrays
weather_data = pd.DataFrame({"City":City,
                             "Country":Country,
                             "Latitude":Lat,
                             "Longitude":Lng,
                             "Date":Date,
                             "Cloudiness":Cloudiness,
                             "Humidity":Humidity,
                             "Max Temp":Max_Temp,
                             "Wind Speed":Wind_Speed})

# Export file as a CSV, without the Pandas index, but with the header
weather_data.to_csv("Output Data/Weather Data.csv", index=False, header=True)

# Mapping lets you format an entire DataFrame
file = "Output Data/Weather Data.csv"
weather_df = pd.read_csv(file)
weather_df.head()
# Out:
#            City Country  Latitude  Longitude        Date  Cloudiness  \
# 0       Rikitea      PF    -23.12    -134.97  1549139992           0
# 1     Mahebourg      MU    -20.41      57.70  1549137600          20
# 2        Castro      CL    -42.48     -73.76  1549137600           0
# 3        Atuona      PF     -9.80    -139.03  1549139993          44
# 4  Ponta do Sol      BR    -20.63     -46.00  1549139994           0
#
#    Humidity  Max Temp  Wind Speed
# 0       100     80.65        8.61
# 1        83     77.00        4.70
# 2        32     84.20       10.29
# 3       100     80.79       18.57
# 4        54     86.77        2.91

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
plt.scatter(weather_df['Latitude'], weather_df['Max Temp'], marker="o", facecolors="blue", edgecolors="black",
            s=50, alpha=0.5)


plt.xlabel("Latitude")
plt.ylabel("Max Tempersture (F)")
plt.title("City Latitude vs. Max Temperature")
plt.grid()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
plt.scatter(weather_df['Latitude'], weather_df['Humidity'], marker="o", facecolors="blue", edgecolors="black",
            s=50, alpha=0.5)


plt.xlabel("Latitude")
plt.ylabel("Humididty (%)")
plt.title("City Latitude vs. Humidity")
plt.grid()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
plt.scatter(weather_df['Latitude'], weather_df['Cloudiness'], marker="o", facecolors="blue", edgecolors="black",
            s=50, alpha=0.5)


plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.title("City Latitude vs. Cloudiness")
plt.grid()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
plt.scatter(weather_df['Latitude'], weather_df['Wind Speed'], marker="o", facecolors="blue", edgecolors="black",
            s=50, alpha=0.5)


plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.title("City Latitude vs. Wind Speed")
plt.grid()
